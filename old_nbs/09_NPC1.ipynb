# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
npc1a = pd.read_json("/data/dzeiberg/mave_calibration/processed_datasets/Erwood_NPC1_HEK293T_pipeline_C.json")
npc1b = pd.read_json("/data/dzeiberg/mave_calibration/processed_datasets/Erwood_NPC1_RPE1_pipeline_C.json")

# %%
npc1a
# Out:
#      CHROM       POS REF ALT  index Protein Annotation Wild type Base  \
# 0       18  23536837   A   T      0             L1027L              T
# 1       18  23536837   A   G      1             L1027L              T
# 2       18  23536837   A   C      2             L1027L              T
# 3       18  23536836   C   T      3             G1028S              G
# 4       18  23536836   C   G      4             G1028R              G
# ..     ...       ...  ..  ..    ...                ...            ...
# 973     18  23539849   C   G    973              L919L              G
# 974     18  23539849   C   A    974              L919L              G
# 975     18  23539848   C   T    975              V920M              G
# 976     18  23539848   C   G    976              V920L              G
# 977     18  23539848   C   A    977              V920L              G
#
#     Edited Base   CDS Consequence SPE Classification  Function Score  \
# ...

# %%
npc1b
# Out:
#      CHROM       POS REF ALT  index Protein Annotation Wild type Base  \
# 0       18  23536837   A   T      0             L1027L              T
# 1       18  23536837   A   G      1             L1027L              T
# 2       18  23536837   A   C      2             L1027L              T
# 3       18  23536836   C   T      3             G1028S              G
# 4       18  23536836   C   G      4             G1028R              G
# ..     ...       ...  ..  ..    ...                ...            ...
# 973     18  23539849   C   G    973              L919L              G
# 974     18  23539849   C   A    974              L919L              G
# 975     18  23539848   C   T    975              V920M              G
# 976     18  23539848   C   G    976              V920L              G
# 977     18  23539848   C   A    977              V920L              G
#
#     Edited Base   CDS Consequence SPE Classification  Function Score  \
# ...
